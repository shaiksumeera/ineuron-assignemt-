# %% [markdown]
# # In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and coloureach data point with specific class.

# %% [markdown]
# # import numpy as npimport matplotlib.pyplot as pltfrom mpl_toolkits.mplot3d import Axes3Dfrom sklearn import decompositionfrom sklearn import datasets

# %%
import numpy as np 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
import pandas as pd
import seaborn as sns
df = datasets.load_iris()

# %%
x=df.data
y=df.target

# %%
from sklearn.decomposition import PCA

# %%
p = PCA(n_components=3)
X=p.fit_transform(x)

# %%
fig=plt.figure(1,figsize=(10,5))
plt.clf()
ax = Axes3D(fig,elev=48, azim=134)
plt.cla()
ax.scatter(X[:,0],X[:,1],X[:,2],c=y,cmap=plt.cm.nipy_spectral,edgecolor='k')
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_title("THE first 3D")
ax.set_xlabel("First axis")
ax.set_ylabel('second axis')
ax.set_zlabel('third axis')
# Out:
# Text(0.5, 0, 'third axis')
